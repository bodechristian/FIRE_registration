# %%
import os
import cv2
import shutil
import numpy as np

from skimage import io
from pathlib import Path

# %%
# Number of extra pairs for each image
nb_extra_pairs = 5

# Paths of input folders and output folders (from current working directory)
# Input folder should consist of an even number of images, where always 2 pictures create a pair
# 1st picture will be moved, 2nd will remain static
path_imgs_in = "Images"
path_imgs_out = "Images_rotated"
# New ground truths will be created (by rotating first point like picture) so that evaluation is possible
path_gts_in = "Ground Truth"
path_gts_out = "ground_truths_rotated"

# Creates output directories if they don't yet exist
Path(path_imgs_out).mkdir(parents=True, exist_ok=True)
Path(path_gts_out).mkdir(parents=True, exist_ok=True)

# Maximum allowed rotation for the first picture, value for both directions [-max_rot, max_rot)
max_rot = 30

# %%
# Get input folder of image pairs
image_names = os.listdir(os.path.join(os.getcwd(), path_imgs_in))

# Use every second index to get pairs
for j in range(0, len(image_names), 2):
    # VARIABLES
    
    # Get Names of Images
    image_name1 = image_names[j]
    image_name2 = image_names[j+1]
    
    # Get Groundtruth name
    pair_name = image_name1[:3] 
    gt_path = os.path.join(os.getcwd(), path_gts_in) 
    gt_name = "control_points_" + pair_name + "_1_2.txt"
    
    # Do it nb_extra_pairs times for each image pair in the in-folder
    for i in range(nb_extra_pairs):
        # Create random rotation
        rotation = round(np.random.rand()*2*max_rot - max_rot)

        # Change output names of files to have rotation degree in it for distinction
        # Naming convention: Pairname _ rotDEGREE _ index-of-img-in-pair . fileending
        # rsplit here splits at the last ".", [:-2] is to cut off the index-of-img-in-pair
        im1_name_out = image_name1.rsplit(".", 1)[0][:-2] +"_rot"+ str(rotation) + "_1.jpg"
        im2_name_out = image_name2.rsplit(".", 1)[0][:-2] +"_rot"+ str(rotation) + "_2.jpg"
        gt_name_out = gt_name.rsplit(".", 1)[0] +"_rot"+ str(rotation) +".txt"     


        # IMAGE

        # Load image and rotate
        im1 = io.imread(os.path.join(path_imgs_in, image_name1))
        # normalize if nessecary
        if np.max(im1) > 1:
            im1 = im1 / 255  
        # get rotation matrix with center in the middle of the first image
        rotate_matrix = cv2.getRotationMatrix2D(center=(im1.shape[0]//2, im1.shape[1]//2), angle=rotation, scale=1)
        im1_rot = cv2.warpAffine(src=im1, M=rotate_matrix, dsize=(im1.shape[0], im1.shape[1]))

        # Converse image to uint8 for saving 
        if np.max(im1_rot) <= 1:
            im1_rot *= 256
        im1_rot = im1_rot.astype("uint8")
        io.imsave(os.path.join(os.getcwd(), path_imgs_out, im1_name_out), im1_rot)

        # Load the fixed image and save it in new folder as well, so that pairs are together
        im2 = io.imread(os.path.join(path_imgs_in, image_name2))
        io.imsave(os.path.join(os.getcwd(), path_imgs_out, im2_name_out), im2)


        # GROUND TRUTHS

        # Read the ground truths and rotate first point accordingly just like the image
        # Write new ground truths into the gt_out folder
        with open(os.path.join(path_gts_in, gt_name), "r") as f_in:  
            with open(os.path.join(os.getcwd(), path_gts_out, gt_name_out), "w") as f_out:                     
                lines = f_in.readlines()  
                for line in lines:
                    # Read the values in the file
                    values = [float(x) for x in line[:-1].split(" ")]
                    # first 2 values are point on the rotated image
                    point1 = np.asarray([[values[0], values[1]]])
                    # rotate these points as well
                    point1_rot = np.matmul(point1, rotate_matrix)[0, :2]

                    # 1st point rotated, 2nd point the same
                    f_out.write(f"{round(point1_rot[0])} {round(point1_rot[1])} {values[2]} {values[3]}\n")  
        
        print(f"Finished {i+1}/{nb_extra_pairs} for pair {pair_name}")
    print(f"Pair {pair_name} done. {j//2 +1}/{len(image_names)//2}\n")
# Out:
# Finished 1/5 for pair A01
# Finished 2/5 for pair A01
# Finished 3/5 for pair A01
# Finished 4/5 for pair A01
# Finished 5/5 for pair A01
# Pair A01 done. 1/134
#
# Finished 1/5 for pair A02
# Finished 2/5 for pair A02
# Finished 3/5 for pair A02
# Finished 4/5 for pair A02
# Finished 5/5 for pair A02
# Pair A02 done. 2/134
#
# Finished 1/5 for pair A03
# Finished 2/5 for pair A03
# Finished 3/5 for pair A03
# Finished 4/5 for pair A03
# Finished 5/5 for pair A03
# Pair A03 done. 3/134
#
# Finished 1/5 for pair A04
# Finished 2/5 for pair A04
# Finished 3/5 for pair A04
# Finished 4/5 for pair A04
# Finished 5/5 for pair A04
# Pair A04 done. 4/134
#
# Finished 1/5 for pair A05
# Finished 2/5 for pair A05
# Finished 3/5 for pair A05
# Finished 4/5 for pair A05
# Finished 5/5 for pair A05
# Pair A05 done. 5/134
#
# Finished 1/5 for pair A06
# Finished 2/5 for pair A06
# Finished 3/5 for pair A06
# Finished 4/5 for pair A06
# Finished 5/5 for pair A06
# Pair A06 done. 6/134
#
# Finished 1/5 for pair A07
# Finished 2/5 for pair A07
# Finished 3/5 for pair A07
# Finished 4/5 for pair A07
# Finished 5/5 for pair A07
# Pair A07 done. 7/134
#
# Finished 1/5 for pair A08
# Finished 2/5 for pair A08
# Finished 3/5 for pair A08
# Finished 4/5 for pair A08
# Finished 5/5 for pair A08
# Pair A08 done. 8/134
#
# Finished 1/5 for pair A09
# Finished 2/5 for pair A09
# Finished 3/5 for pair A09
# Finished 4/5 for pair A09
# Finished 5/5 for pair A09
# Pair A09 done. 9/134
#
# Finished 1/5 for pair A10
# Finished 2/5 for pair A10
# Finished 3/5 for pair A10
# Finished 4/5 for pair A10
# Finished 5/5 for pair A10
# Pair A10 done. 10/134
#
# Finished 1/5 for pair A11
# Finished 2/5 for pair A11
# Finished 3/5 for pair A11
# Finished 4/5 for pair A11
# Finished 5/5 for pair A11
# Pair A11 done. 11/134
#
# Finished 1/5 for pair A12
# Finished 2/5 for pair A12
# Finished 3/5 for pair A12
# Finished 4/5 for pair A12
# Finished 5/5 for pair A12
# Pair A12 done. 12/134
#
# Finished 1/5 for pair A13
# Finished 2/5 for pair A13
# Finished 3/5 for pair A13
# Finished 4/5 for pair A13
# Finished 5/5 for pair A13
# Pair A13 done. 13/134
#
# Finished 1/5 for pair A14
# Finished 2/5 for pair A14
# Finished 3/5 for pair A14
# Finished 4/5 for pair A14
# Finished 5/5 for pair A14
# Pair A14 done. 14/134
#
# Finished 1/5 for pair P01
# Finished 2/5 for pair P01
# Finished 3/5 for pair P01
# Finished 4/5 for pair P01
# Finished 5/5 for pair P01
# Pair P01 done. 15/134
#
# Finished 1/5 for pair P02
# Finished 2/5 for pair P02
# Finished 3/5 for pair P02
# Finished 4/5 for pair P02
# Finished 5/5 for pair P02
# Pair P02 done. 16/134
#
# Finished 1/5 for pair P03
# Finished 2/5 for pair P03
# Finished 3/5 for pair P03
# Finished 4/5 for pair P03
# Finished 5/5 for pair P03
# Pair P03 done. 17/134
#
# Finished 1/5 for pair P04
# Finished 2/5 for pair P04
# Finished 3/5 for pair P04
# Finished 4/5 for pair P04
# Finished 5/5 for pair P04
# Pair P04 done. 18/134
#
# Finished 1/5 for pair P05
# Finished 2/5 for pair P05
# Finished 3/5 for pair P05
# Finished 4/5 for pair P05
# Finished 5/5 for pair P05
# Pair P05 done. 19/134
#
# Finished 1/5 for pair P06
# Finished 2/5 for pair P06
# Finished 3/5 for pair P06
# Finished 4/5 for pair P06
# Finished 5/5 for pair P06
# Pair P06 done. 20/134
#
# Finished 1/5 for pair P07
# Finished 2/5 for pair P07
# Finished 3/5 for pair P07
# Finished 4/5 for pair P07
# Finished 5/5 for pair P07
# Pair P07 done. 21/134
#
# Finished 1/5 for pair P08
# Finished 2/5 for pair P08
# Finished 3/5 for pair P08
# Finished 4/5 for pair P08
# Finished 5/5 for pair P08
# Pair P08 done. 22/134
#
# Finished 1/5 for pair P09
# Finished 2/5 for pair P09
# Finished 3/5 for pair P09
# Finished 4/5 for pair P09
# Finished 5/5 for pair P09
# Pair P09 done. 23/134
#
# Finished 1/5 for pair P10
# Finished 2/5 for pair P10
# Finished 3/5 for pair P10
# Finished 4/5 for pair P10
# Finished 5/5 for pair P10
# Pair P10 done. 24/134
#
# Finished 1/5 for pair P11
# Finished 2/5 for pair P11
# Finished 3/5 for pair P11
# Finished 4/5 for pair P11
# Finished 5/5 for pair P11
# Pair P11 done. 25/134
#
# Finished 1/5 for pair P12
# Finished 2/5 for pair P12
# Finished 3/5 for pair P12
# Finished 4/5 for pair P12
# Finished 5/5 for pair P12
# Pair P12 done. 26/134
#
# Finished 1/5 for pair P13
# Finished 2/5 for pair P13
# Finished 3/5 for pair P13
# Finished 4/5 for pair P13
# Finished 5/5 for pair P13
# Pair P13 done. 27/134
#
# Finished 1/5 for pair P14
# Finished 2/5 for pair P14
# Finished 3/5 for pair P14
# Finished 4/5 for pair P14
# Finished 5/5 for pair P14
# Pair P14 done. 28/134
#
# Finished 1/5 for pair P15
# Finished 2/5 for pair P15
# Finished 3/5 for pair P15
# Finished 4/5 for pair P15
# Finished 5/5 for pair P15
# Pair P15 done. 29/134
#
# Finished 1/5 for pair P16
# Finished 2/5 for pair P16
# Finished 3/5 for pair P16
# Finished 4/5 for pair P16
# Finished 5/5 for pair P16
# Pair P16 done. 30/134
#
# Finished 1/5 for pair P17
# Finished 2/5 for pair P17
# Finished 3/5 for pair P17
# Finished 4/5 for pair P17
# Finished 5/5 for pair P17
# Pair P17 done. 31/134
#
# Finished 1/5 for pair P18
# Finished 2/5 for pair P18
# Finished 3/5 for pair P18
# Finished 4/5 for pair P18
# Finished 5/5 for pair P18
# Pair P18 done. 32/134
#
# Finished 1/5 for pair P19
# Finished 2/5 for pair P19
# Finished 3/5 for pair P19
# Finished 4/5 for pair P19
# Finished 5/5 for pair P19
# Pair P19 done. 33/134
#
# Finished 1/5 for pair P20
# Finished 2/5 for pair P20
# Finished 3/5 for pair P20
# Finished 4/5 for pair P20
# Finished 5/5 for pair P20
# Pair P20 done. 34/134
#
# Finished 1/5 for pair P21
# Finished 2/5 for pair P21
# Finished 3/5 for pair P21
# Finished 4/5 for pair P21
# Finished 5/5 for pair P21
# Pair P21 done. 35/134
#
# Finished 1/5 for pair P22
# Finished 2/5 for pair P22
# Finished 3/5 for pair P22
# Finished 4/5 for pair P22
# Finished 5/5 for pair P22
# Pair P22 done. 36/134
#
# Finished 1/5 for pair P23
# Finished 2/5 for pair P23
# Finished 3/5 for pair P23
# Finished 4/5 for pair P23
# Finished 5/5 for pair P23
# Pair P23 done. 37/134
#
# Finished 1/5 for pair P24
# Finished 2/5 for pair P24
# Finished 3/5 for pair P24
# Finished 4/5 for pair P24
# Finished 5/5 for pair P24
# Pair P24 done. 38/134
#
# Finished 1/5 for pair P25
# Finished 2/5 for pair P25
# Finished 3/5 for pair P25
# Finished 4/5 for pair P25
# Finished 5/5 for pair P25
# Pair P25 done. 39/134
#
# Finished 1/5 for pair P26
# Finished 2/5 for pair P26
# Finished 3/5 for pair P26
# Finished 4/5 for pair P26
# Finished 5/5 for pair P26
# Pair P26 done. 40/134
#
# Finished 1/5 for pair P27
# Finished 2/5 for pair P27
# Finished 3/5 for pair P27
# Finished 4/5 for pair P27
# Finished 5/5 for pair P27
# Pair P27 done. 41/134
#
# Finished 1/5 for pair P28
# Finished 2/5 for pair P28
# Finished 3/5 for pair P28
# Finished 4/5 for pair P28
# Finished 5/5 for pair P28
# Pair P28 done. 42/134
#
# Finished 1/5 for pair P29
# Finished 2/5 for pair P29
# Finished 3/5 for pair P29
# Finished 4/5 for pair P29
# Finished 5/5 for pair P29
# Pair P29 done. 43/134
#
# Finished 1/5 for pair P30
# Finished 2/5 for pair P30
# Finished 3/5 for pair P30
# Finished 4/5 for pair P30
# Finished 5/5 for pair P30
# Pair P30 done. 44/134
#
# Finished 1/5 for pair P31
# Finished 2/5 for pair P31
# Finished 3/5 for pair P31
# Finished 4/5 for pair P31
# Finished 5/5 for pair P31
# Pair P31 done. 45/134
#
# Finished 1/5 for pair P32
# Finished 2/5 for pair P32
# Finished 3/5 for pair P32
# Finished 4/5 for pair P32
# Finished 5/5 for pair P32
# Pair P32 done. 46/134
#
# Finished 1/5 for pair P33
# Finished 2/5 for pair P33
# Finished 3/5 for pair P33
# Finished 4/5 for pair P33
# Finished 5/5 for pair P33
# Pair P33 done. 47/134
#
# Finished 1/5 for pair P34
# Finished 2/5 for pair P34
# Finished 3/5 for pair P34
# Finished 4/5 for pair P34
# Finished 5/5 for pair P34
# Pair P34 done. 48/134
#
# Finished 1/5 for pair P35
# Finished 2/5 for pair P35
# Finished 3/5 for pair P35
# Finished 4/5 for pair P35
# Finished 5/5 for pair P35
# Pair P35 done. 49/134
#
# Finished 1/5 for pair P36
# Finished 2/5 for pair P36
# Finished 3/5 for pair P36
# Finished 4/5 for pair P36
# Finished 5/5 for pair P36
# Pair P36 done. 50/134
#
# Finished 1/5 for pair P37
# Finished 2/5 for pair P37
# Finished 3/5 for pair P37
# Finished 4/5 for pair P37
# Finished 5/5 for pair P37
# Pair P37 done. 51/134
#
# Finished 1/5 for pair P38
# Finished 2/5 for pair P38
# Finished 3/5 for pair P38
# Finished 4/5 for pair P38
# Finished 5/5 for pair P38
# Pair P38 done. 52/134
#
# Finished 1/5 for pair P39
# Finished 2/5 for pair P39
# Finished 3/5 for pair P39
# Finished 4/5 for pair P39
# Finished 5/5 for pair P39
# Pair P39 done. 53/134
#
# Finished 1/5 for pair P40
# Finished 2/5 for pair P40
# Finished 3/5 for pair P40
# Finished 4/5 for pair P40
# Finished 5/5 for pair P40
# Pair P40 done. 54/134
#
# Finished 1/5 for pair P41
# Finished 2/5 for pair P41
# Finished 3/5 for pair P41
# Finished 4/5 for pair P41
# Finished 5/5 for pair P41
# Pair P41 done. 55/134
#
# Finished 1/5 for pair P42
# Finished 2/5 for pair P42
# Finished 3/5 for pair P42
# Finished 4/5 for pair P42
# Finished 5/5 for pair P42
# Pair P42 done. 56/134
#
# Finished 1/5 for pair P43
# Finished 2/5 for pair P43
# Finished 3/5 for pair P43
# Finished 4/5 for pair P43
# Finished 5/5 for pair P43
# Pair P43 done. 57/134
#
# Finished 1/5 for pair P44
# Finished 2/5 for pair P44
# Finished 3/5 for pair P44
# Finished 4/5 for pair P44
# Finished 5/5 for pair P44
# Pair P44 done. 58/134
#
# Finished 1/5 for pair P45
# Finished 2/5 for pair P45
# Finished 3/5 for pair P45
# Finished 4/5 for pair P45
# Finished 5/5 for pair P45
# Pair P45 done. 59/134
#
# Finished 1/5 for pair P46
# Finished 2/5 for pair P46
# Finished 3/5 for pair P46
# Finished 4/5 for pair P46
# Finished 5/5 for pair P46
# Pair P46 done. 60/134
#
# Finished 1/5 for pair P47
# Finished 2/5 for pair P47
# Finished 3/5 for pair P47
# Finished 4/5 for pair P47
# Finished 5/5 for pair P47
# Pair P47 done. 61/134
#
# Finished 1/5 for pair P48
# Finished 2/5 for pair P48
# Finished 3/5 for pair P48
# Finished 4/5 for pair P48
# Finished 5/5 for pair P48
# Pair P48 done. 62/134
#
# Finished 1/5 for pair P49
# Finished 2/5 for pair P49
# Finished 3/5 for pair P49
# Finished 4/5 for pair P49
# Finished 5/5 for pair P49
# Pair P49 done. 63/134
#
# Finished 1/5 for pair S01
# Finished 2/5 for pair S01
# Finished 3/5 for pair S01
# Finished 4/5 for pair S01
# Finished 5/5 for pair S01
# Pair S01 done. 64/134
#
# Finished 1/5 for pair S02
# Finished 2/5 for pair S02
# Finished 3/5 for pair S02
# Finished 4/5 for pair S02
# Finished 5/5 for pair S02
# Pair S02 done. 65/134
#
# Finished 1/5 for pair S03
# Finished 2/5 for pair S03
# Finished 3/5 for pair S03
# Finished 4/5 for pair S03
# Finished 5/5 for pair S03
# Pair S20 done. 83/134
#
# Finished 1/5 for pair S21
# Finished 2/5 for pair S21
# Finished 3/5 for pair S21
# Finished 4/5 for pair S21
# Finished 5/5 for pair S21
# Pair S21 done. 84/134
#
# Finished 1/5 for pair S22
# Finished 2/5 for pair S22
# Finished 3/5 for pair S22
# Finished 4/5 for pair S22
# Finished 5/5 for pair S22
# Pair S22 done. 85/134
#
# Finished 1/5 for pair S23
# Finished 2/5 for pair S23
# Finished 3/5 for pair S23
# Finished 4/5 for pair S23
# Finished 5/5 for pair S23
# Pair S23 done. 86/134
#
# Finished 1/5 for pair S24
# Finished 2/5 for pair S24
# Finished 3/5 for pair S24
# Finished 4/5 for pair S24
# Finished 5/5 for pair S24
# Pair S24 done. 87/134
#
# Finished 1/5 for pair S25
# Finished 2/5 for pair S25
# Finished 3/5 for pair S25
# Finished 4/5 for pair S25
# Finished 5/5 for pair S25
# Pair S25 done. 88/134
#
# Finished 1/5 for pair S26
# Finished 2/5 for pair S26
# Finished 3/5 for pair S26
# Finished 4/5 for pair S26
# Finished 5/5 for pair S26
# Pair S26 done. 89/134
#
# Finished 1/5 for pair S27
# Finished 2/5 for pair S27
# Finished 3/5 for pair S27
# Finished 4/5 for pair S27
# Finished 5/5 for pair S27
# Pair S27 done. 90/134
#
# Finished 1/5 for pair S28
# Finished 2/5 for pair S28
# Finished 3/5 for pair S28
# Finished 4/5 for pair S28
# Finished 5/5 for pair S28
# Pair S28 done. 91/134
#
# Finished 1/5 for pair S29
# Finished 2/5 for pair S29
# Finished 3/5 for pair S29
# Finished 4/5 for pair S29
# Finished 5/5 for pair S29
# Pair S29 done. 92/134
#
# Finished 1/5 for pair S30
# Finished 2/5 for pair S30
# Finished 3/5 for pair S30
# Finished 4/5 for pair S30
# Finished 5/5 for pair S30
# Pair S30 done. 93/134
#
# Finished 1/5 for pair S31
# Finished 2/5 for pair S31
# Finished 3/5 for pair S31
# Finished 4/5 for pair S31
# Finished 5/5 for pair S31
# Pair S31 done. 94/134
#
# Finished 1/5 for pair S32
# Finished 2/5 for pair S32
# Finished 3/5 for pair S32
# Finished 4/5 for pair S32
# Finished 5/5 for pair S32
# Pair S32 done. 95/134
#
# Finished 1/5 for pair S33
# Finished 2/5 for pair S33
# Finished 3/5 for pair S33
# Finished 4/5 for pair S33
# Finished 5/5 for pair S33
# Pair S33 done. 96/134
#
# Finished 1/5 for pair S34
# Finished 2/5 for pair S34
# Finished 3/5 for pair S34
# Finished 4/5 for pair S34
# Finished 5/5 for pair S34
# Pair S34 done. 97/134
#
# Finished 1/5 for pair S35
# Finished 2/5 for pair S35
# Finished 3/5 for pair S35
# Finished 4/5 for pair S35
# Finished 5/5 for pair S35
# Pair S35 done. 98/134
#
# Finished 1/5 for pair S36
# Finished 2/5 for pair S36
# Finished 3/5 for pair S36
# Finished 4/5 for pair S36
# Finished 5/5 for pair S36
# Pair S36 done. 99/134
#
# Finished 1/5 for pair S37
# Finished 2/5 for pair S37
# Finished 3/5 for pair S37
# Finished 4/5 for pair S37
# Finished 5/5 for pair S37
# Pair S37 done. 100/134
#
# Finished 1/5 for pair S55
# Finished 2/5 for pair S55
# Finished 3/5 for pair S55
# Finished 4/5 for pair S55
# Finished 5/5 for pair S55
# Pair S55 done. 118/134
#
# Finished 1/5 for pair S56
# Finished 2/5 for pair S56
# Finished 3/5 for pair S56
# Finished 4/5 for pair S56
# Finished 5/5 for pair S56
# Pair S56 done. 119/134
#
# Finished 1/5 for pair S57
# Finished 2/5 for pair S57
# Finished 3/5 for pair S57
# Finished 4/5 for pair S57
# Finished 5/5 for pair S57
# Pair S57 done. 120/134
#
# Finished 1/5 for pair S58
# Finished 2/5 for pair S58
# Finished 3/5 for pair S58
# Finished 4/5 for pair S58
# Finished 5/5 for pair S58
# Pair S58 done. 121/134
#
# Finished 1/5 for pair S59
# Finished 2/5 for pair S59
# Finished 3/5 for pair S59
# Finished 4/5 for pair S59
# Finished 5/5 for pair S59
# Pair S59 done. 122/134
#
# Finished 1/5 for pair S60
# Finished 2/5 for pair S60
# Finished 3/5 for pair S60
# Finished 4/5 for pair S60
# Finished 5/5 for pair S60
# Pair S60 done. 123/134
#
# Finished 1/5 for pair S61
# Finished 2/5 for pair S61
# Finished 3/5 for pair S61
# Finished 4/5 for pair S61
# Finished 5/5 for pair S61
# Pair S61 done. 124/134
#
# Finished 1/5 for pair S62
# Finished 2/5 for pair S62
# Finished 3/5 for pair S62
# Finished 4/5 for pair S62
# Finished 5/5 for pair S62
# Pair S62 done. 125/134
#
# Finished 1/5 for pair S63
# Finished 2/5 for pair S63
# Finished 3/5 for pair S63
# Finished 4/5 for pair S63
# Finished 5/5 for pair S63
# Pair S63 done. 126/134
#
# Finished 1/5 for pair S64
# Finished 2/5 for pair S64
# Finished 3/5 for pair S64
# Finished 4/5 for pair S64
# Finished 5/5 for pair S64
# Pair S64 done. 127/134
#
# Finished 1/5 for pair S65
# Finished 2/5 for pair S65
# Finished 3/5 for pair S65
# Finished 4/5 for pair S65
# Finished 5/5 for pair S65
# Pair S65 done. 128/134
#
# Finished 1/5 for pair S66
# Finished 2/5 for pair S66
# Finished 3/5 for pair S66
# Finished 4/5 for pair S66
# Finished 5/5 for pair S66
# Pair S66 done. 129/134
#
# Finished 1/5 for pair S67
# Finished 2/5 for pair S67
# Finished 3/5 for pair S67
# Finished 4/5 for pair S67
# Finished 5/5 for pair S67
# Pair S67 done. 130/134
#
# Finished 1/5 for pair S68
# Finished 2/5 for pair S68
# Finished 3/5 for pair S68
# Finished 4/5 for pair S68
# Finished 5/5 for pair S68
# Pair S68 done. 131/134
#
# Finished 1/5 for pair S69
# Finished 2/5 for pair S69
# Finished 3/5 for pair S69
# Finished 4/5 for pair S69
# Finished 5/5 for pair S69
# Pair S69 done. 132/134
#
# Finished 1/5 for pair S70
# Finished 2/5 for pair S70
# Finished 3/5 for pair S70
# Finished 4/5 for pair S70
# Finished 5/5 for pair S70
# Pair S70 done. 133/134
#
# Finished 1/5 for pair S71
# Finished 2/5 for pair S71
# Finished 3/5 for pair S71
# Finished 4/5 for pair S71
# Finished 5/5 for pair S71
# Pair S71 done. 134/134
